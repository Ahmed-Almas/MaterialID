# %%
# !pip install opencv-python

# %% [markdown]
# Detection in Video

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = "C:/Users/almas/Downloads/specs/videos/11.mp4"
video_path_out = "C:/Users/almas/Downloads/specs/videos/11r_out.mp4"

cap = cv2.VideoCapture(VIDEOS_DIR)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*"MP4V"), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = "C:/Users/almas/Downloads/specs/runs/detect/train/weights/last.pt"


model = YOLO(model_path)  

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 plastic frame, 512.6ms
# Speed: 0.0ms preprocess, 512.6ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 392.5ms
# Speed: 4.3ms preprocess, 392.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 466.8ms
# Speed: 3.8ms preprocess, 466.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 432.3ms
# Speed: 3.1ms preprocess, 432.3ms inference, 14.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 403.2ms
# Speed: 1.5ms preprocess, 403.2ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 447.5ms
# Speed: 15.5ms preprocess, 447.5ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 1 plastic frame, 433.8ms
# Speed: 3.8ms preprocess, 433.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# ...

# %% [markdown]
# Detection in Images

# %%
import os

from ultralytics import YOLO
import cv2


VIDEOS_DIR = "C:/Users/almas/Downloads/specs/videos/r1.jpg"
video_path_out = "C:/Users/almas/Downloads/specs/videos/r1_out.jpeg"

cap = cv2.VideoCapture(VIDEOS_DIR)
ret, frame = cap.read()
H, W, _ = frame.shape
out = cv2.VideoWriter(video_path_out, cv2.VideoWriter_fourcc(*"JPEG"), int(cap.get(cv2.CAP_PROP_FPS)), (W, H))

model_path = "C:/Users/almas/Downloads/specs/runs/detect/train/weights/best.pt"

# Load a model
model = YOLO(model_path)  # load a custom model

threshold = 0.5

while ret:

    results = model(frame)[0]

    for result in results.boxes.data.tolist():
        x1, y1, x2, y2, score, class_id = result

        if score > threshold:
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 4)
            cv2.putText(frame, results.names[int(class_id)].upper(), (int(x1), int(y1 - 10)),
                        cv2.FONT_HERSHEY_SIMPLEX, 1.3, (0, 255, 0), 3, cv2.LINE_AA)

    out.write(frame)
    ret, frame = cap.read()

cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# 0: 384x640 1 plastic frame, 451.1ms
# Speed: 14.0ms preprocess, 451.1ms inference, 1472.7ms postprocess per image at shape (1, 3, 384, 640)
